# %% [markdown]
# # Basic usage
#
# This notebook demonstrates `generate_dataset` with a small inline schema. For YAML and the CLI, see the project README and `examples/users_schema.yaml`.

# %%
from data_generator import generate_dataset

schema = {
    "name": {"type": "name"},
    "age": {"type": "int", "min": 18, "max": 80},
    "city": {"type": "choice", "values": ["Rio", "São Paulo", "Curitiba"]},
}

df = generate_dataset(5, schema, seed=7)
df
